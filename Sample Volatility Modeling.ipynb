# %% [markdown]
# ## Volatility Modeling Example

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import datetime
from statsmodels.tsa.stattools import adfuller as adf
import statsmodels.api as sm
import pmdarima
from arch import arch_model
from collections import OrderedDict
import datetime as dt
import itertools

# %%
###########Input Files
mkt_data_file='MarketData.csv'

####1. Read in market data file
mkt_data=pd.read_csv(mkt_data_file)
mkt_data['Date']=pd.to_datetime(mkt_data['Date'])

mkt_data.set_index('Date', inplace=True)
mkt_data['S&P 500']=mkt_data['S&P 500'].astype(float)

mkt_data.head()
# Out:
#             S&P 500
# Date
# 2009-12-31  1115.10
# 2010-01-04  1132.98
# 2010-01-05  1136.52
# 2010-01-06  1137.14
# 2010-01-07  1141.70

# %% [markdown]
# ### Compare underlying distribution

# %%
def distribution_selection(data):
    """
    evaluate LLF based on underlying distribution
    """
    res_normal = arch_model(data).fit(disp="off")
    res_t = arch_model(data, dist="t").fit(disp="off")
    res_skewt = arch_model(data, dist="skewt").fit(disp="off")
    lls = pd.Series(OrderedDict((("normal", res_normal.loglikelihood),("t", res_t.loglikelihood),
                                 ("skewt", res_skewt.loglikelihood))))
    print(lls)
    params = pd.DataFrame(OrderedDict((("normal", res_normal.params),("t", res_t.params),("skewt", res_skewt.params),)))
    print(params)

# %%
mkt_data_shifted = mkt_data['S&P 500'].shift(1)
mkt_data['daily_Return'] = np.log(mkt_data['S&P 500']/mkt_data_shifted) #daily returns
mkt_data_shifted=mkt_data['S&P 500'].shift(5)
mkt_data['weekly_Return'] = np.log(mkt_data['S&P 500']/mkt_data_shifted) #weekly returns
mkt_data_shifted=mkt_data['S&P 500'].shift(22)
mkt_data['monthly_Return'] = np.log(mkt_data['S&P 500']/mkt_data_shifted) #monthly returns
mkt_data.dropna(inplace = True)
mkt_data
# Out:
#             S&P 500  daily_Return  weekly_Return  monthly_Return
# Date
# 2010-02-03  1097.28     -0.005489      -0.000200       -0.016110
# 2010-02-04  1063.11     -0.031636      -0.019948       -0.063653
# 2010-02-05  1066.19      0.002893      -0.007177       -0.063879
# 2010-02-08  1056.74     -0.008903      -0.030246       -0.073328
# 2010-02-09  1070.52      0.012956      -0.030179       -0.064374
# ...             ...           ...            ...             ...
# 2021-05-24  4197.05      0.009863       0.008076        0.014899
# 2021-05-25  4188.13     -0.002128       0.014502        0.001902
# 2021-05-26  4195.99      0.001875       0.019325        0.001997
# 2021-05-27  4200.88      0.001165       0.009991        0.003376
# 2021-05-28  4204.11      0.000769       0.011543        0.004991
#
# [2850 rows x 4 columns]

# %%
distribution_selection(mkt_data['weekly_Return']*100) #scale returns first and then compare NLL of the 3 distributions
# Out:
# normal   -5334.705295
# t        -5328.130269
# skewt    -5319.367328
# dtype: float64
#             normal          t      skewt
# alpha[1]  0.500838   0.560082   0.510045
# beta[1]   0.499162   0.439918   0.489955
# lambda         NaN        NaN  -0.158133
# mu        0.527308   0.525295   0.447177
# nu             NaN  20.150491  26.729264
# omega     0.207815   0.245353   0.207687

# %% [markdown]
# ##### skewt distribution is the winner based on NLL

# %%
#best model based on LLF
results=pd.DataFrame()

#iterate through different returns and volatility models
for item in list(itertools.product(['monthly_Return','weekly_return','daily_return'],['FIGARCH','GARCH','EGARCH'])):
    if item[0] =='daily_Return':
        t=252
        shift='D'
        data_range=148
    elif item[0] == 'weekly_Return':
        t=52
        shift='W-MON'
    else:
        t=12
        shift='M'
        data_range=67
        
    SP_return = mkt_data.resample(shift).ffill().pct_change().dropna() #calculate daily, weekly, or monthly returns

    index = SP_return.index

    end_loc = np.where(index >= "2015-12-31")[0].min() #last data point

    forecasts = {}
    
    if item[1]=='FIGARCH':
        model = arch_model(SP_return['S&P 500'], vol=item[1],  p=1, q=1, dist='skewt', rescale = True)
    else:
        model = arch_model(SP_return['S&P 500'], vol=item[1],  p=2, o=0, q=2, dist='skewt', rescale = True)
    
    for i in range(0,data_range):
        model_fit = model.fit(first_obs=1, last_obs=i + end_loc,update_freq=4)
        var = model_fit.forecast(horizon=1,reindex=False).variance
        
        fcast = var.iloc[0]
        forecasts[fcast.name]=fcast
        df=pd.DataFrame(forecasts).T
        df.columns=[item[0]+item[1]]
    
    print(item)
    print(pd.DataFrame(forecasts).T)
    results=pd.concat([results,df], axis=1)

#results.to_csv(r'results_calibration.csv')
# Out:
# Iteration:      4,   Func. Count:     34,   Neg. LLF: 31.694951628881572
# Iteration:      8,   Func. Count:     65,   Neg. LLF: 26.9827188466405
# Iteration:     12,   Func. Count:     93,   Neg. LLF: 26.969637148835613
# Iteration:     16,   Func. Count:    121,   Neg. LLF: 26.913483680840784
# Iteration:     20,   Func. Count:    151,   Neg. LLF: 26.85742618686145
# Iteration:     24,   Func. Count:    179,   Neg. LLF: 26.84235106371053
# Iteration:     28,   Func. Count:    207,   Neg. LLF: 26.839041729242467
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 26.838660031150788
#             Iterations: 28
#             Function evaluations: 217
#             Gradient evaluations: 28
# Iteration:      4,   Func. Count:     34,   Neg. LLF: 49.78145894719948
# Iteration:      8,   Func. Count:     65,   Neg. LLF: 27.208181062001206
# Iteration:     12,   Func. Count:     93,   Neg. LLF: 27.190053203982966
# Iteration:     16,   Func. Count:    121,   Neg. LLF: 27.076148260046164
# Iteration:     20,   Func. Count:    149,   Neg. LLF: 27.041571369922902
# Iteration:     24,   Func. Count:    178,   Neg. LLF: 27.03424254617459
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 27.033344187121916
#             Iterations: 27
#             Function evaluations: 213
#             Gradient evaluations: 27
# Iteration:      4,   Func. Count:     34,   Neg. LLF: 137.3863685477225
# Iteration:      8,   Func. Count:     65,   Neg. LLF: 28.738391131663214
# Iteration:     12,   Func. Count:     93,   Neg. LLF: 28.663012580470504
# Iteration:     16,   Func. Count:    121,   Neg. LLF: 28.57227747281728
# Iteration:     20,   Func. Count:    149,   Neg. LLF: 28.472148681053465
# Iteration:     24,   Func. Count:    177,   Neg. LLF: 28.471434569437214
# Iteration:     28,   Func. Count:    207,   Neg. LLF: 28.50134004247185
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 28.454351524383636
#             Iterations: 31
#             Function evaluations: 232
#             Gradient evaluations: 31
# Iteration:      4,   Func. Count:     34,   Neg. LLF: 32.48912394353551
# Iteration:      8,   Func. Count:     64,   Neg. LLF: 28.859840444492708
# Iteration:     12,   Func. Count:     92,   Neg. LLF: 28.804505388533634
# Iteration:     16,   Func. Count:    120,   Neg. LLF: 28.67967106921501
# Iteration:     20,   Func. Count:    151,   Neg. LLF: 28.610014929894497
# Iteration:     24,   Func. Count:    179,   Neg. LLF: 28.57152762176875
# Iteration:     28,   Func. Count:    217,   Neg. LLF: 28.56759230432413
# Iteration:     32,   Func. Count:    245,   Neg. LLF: 28.566466639077678
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 28.566463621444566
#             Iterations: 35
#             Function evaluations: 266
#             Gradient evaluations: 35
# Iteration:      4,   Func. Count:     34,   Neg. LLF: 30.302606317052902
# Iteration:      8,   Func. Count:     64,   Neg. LLF: 30.093634776652486
# Iteration:     12,   Func. Count:     93,   Neg. LLF: 30.006465492558775
# Iteration:     16,   Func. Count:    121,   Neg. LLF: 29.92292662643135
# Iteration:     20,   Func. Count:    149,   Neg. LLF: 29.797891157512094
# Iteration:     24,   Func. Count:    177,   Neg. LLF: 29.76185434152986
# Iteration:     28,   Func. Count:    205,   Neg. LLF: 29.813506165674106
# Iteration:     32,   Func. Count:    236,   Neg. LLF: 29.87257138649941
# Iteration:     36,   Func. Count:    269,   Neg. LLF: 29.74474630677688
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 29.744736502826473
#             Iterations: 38
#             Function evaluations: 284
#             Gradient evaluations: 38
# Iteration:      4,   Func. Count:     34,   Neg. LLF: 30.2912987173554
# Iteration:      8,   Func. Count:     65,   Neg. LLF: 30.11550100752621
# Iteration:     12,   Func. Count:     94,   Neg. LLF: 30.398525484904276
# Iteration:     16,   Func. Count:    124,   Neg. LLF: 30.015720136627376
# Iteration:     20,   Func. Count:    152,   Neg. LLF: 29.918772347542617
# Iteration:     24,   Func. Count:    183,   Neg. LLF: 29.82442275132279
# Iteration:     28,   Func. Count:    211,   Neg. LLF: 29.804901409829327
# Iteration:     32,   Func. Count:    240,   Neg. LLF: 29.810115433495213
# Iteration:     36,   Func. Count:    271,   Neg. LLF: 29.796540019033817
# Iteration:     40,   Func. Count:    300,   Neg. LLF: 29.79391831943172
# Iteration:     44,   Func. Count:    329,   Neg. LLF: 29.78986047453762
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 29.78921011513928
#             Iterations: 46
#             Function evaluations: 357
#             Gradient evaluations: 46
# Iteration:      4,   Func. Count:     34,   Neg. LLF: 33.74789133393991
# Iteration:      8,   Func. Count:     64,   Neg. LLF: 29.90545474652022
# Iteration:     12,   Func. Count:     92,   Neg. LLF: 29.850342670562032
# Iteration:     16,   Func. Count:    120,   Neg. LLF: 29.71730274066526
# Iteration:     20,   Func. Count:    149,   Neg. LLF: 29.660379700187203
# Iteration:     24,   Func. Count:    177,   Neg. LLF: 29.6550194439517
# Iteration:     28,   Func. Count:    216,   Neg. LLF: 29.638323336609748
# Iteration:     32,   Func. Count:    244,   Neg. LLF: 29.636396782109014
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 29.636396157109704
#             Iterations: 32
#             Function evaluations: 246
#             Gradient evaluations: 32
# Iteration:      4,   Func. Count:     34,   Neg. LLF: 34.04018870672388
# Iteration:      8,   Func. Count:     64,   Neg. LLF: 29.652549475886985
# Iteration:     12,   Func. Count:     92,   Neg. LLF: 29.618305622728165
# Iteration:     16,   Func. Count:    120,   Neg. LLF: 29.53423310171275
# Iteration:     20,   Func. Count:    148,   Neg. LLF: 29.442546385192514
# Iteration:     24,   Func. Count:    176,   Neg. LLF: 29.43267669540939
# Iteration:     28,   Func. Count:    206,   Neg. LLF: 29.423665175339533
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 29.423508128648777
#             Iterations: 30
#             Function evaluations: 230
#             Gradient evaluations: 30
# Iteration:      4,   Func. Count:     34,   Neg. LLF: 34.55827577502191
# Iteration:      8,   Func. Count:     65,   Neg. LLF: 29.71703281465551
# Iteration:     12,   Func. Count:     93,   Neg. LLF: 29.681594355890695
# Iteration:     16,   Func. Count:    121,   Neg. LLF: 29.610501644797637
# Iteration:     20,   Func. Count:    149,   Neg. LLF: 29.514888570593172
# Iteration:     24,   Func. Count:    177,   Neg. LLF: 29.5031324721507
# Iteration:     28,   Func. Count:    206,   Neg. LLF: 29.497267992571246
# Iteration:     32,   Func. Count:    234,   Neg. LLF: 29.496400165210005
# Iteration:     36,   Func. Count:    263,   Neg. LLF: 29.49498032073695
# Iteration:     40,   Func. Count:    298,   Neg. LLF: 29.49192018742417
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 29.49179567801795
#             Iterations: 43
#             Function evaluations: 323
#             Gradient evaluations: 43
# Iteration:      4,   Func. Count:     36,   Neg. LLF: 31.311990620845435
# Iteration:      8,   Func. Count:     68,   Neg. LLF: 71.32338658094818
# Iteration:     12,   Func. Count:     99,   Neg. LLF: 29.582811612672508
# Iteration:     16,   Func. Count:    128,   Neg. LLF: 29.497073854747896
# Iteration:     20,   Func. Count:    157,   Neg. LLF: 29.462859963636458
# Iteration:     24,   Func. Count:    185,   Neg. LLF: 29.434643686872825
# Iteration:     28,   Func. Count:    213,   Neg. LLF: 29.363571326813556
# Iteration:     32,   Func. Count:    241,   Neg. LLF: 29.31447591653415
# Iteration:     36,   Func. Count:    269,   Neg. LLF: 29.307483650575904
# Iteration:     40,   Func. Count:    302,   Neg. LLF: 29.32085584732549
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 29.302753526624038
#             Iterations: 43
#             Function evaluations: 331
#             Gradient evaluations: 43
# Iteration:      4,   Func. Count:     36,   Neg. LLF: 29.851625034401877
# Iteration:      8,   Func. Count:     68,   Neg. LLF: 30.20286822863431
# Iteration:     12,   Func. Count:     99,   Neg. LLF: 29.290257537886852
# Iteration:     16,   Func. Count:    128,   Neg. LLF: 29.20288103856376
# Iteration:     20,   Func. Count:    156,   Neg. LLF: 29.184111002689846
# Iteration:     24,   Func. Count:    184,   Neg. LLF: 29.09976841863983
# Iteration:     28,   Func. Count:    212,   Neg. LLF: 29.064612185902508
# Iteration:     32,   Func. Count:    240,   Neg. LLF: 29.056814587448127
# Iteration:     36,   Func. Count:    270,   Neg. LLF: 29.060535504550447
# Iteration:     40,   Func. Count:    299,   Neg. LLF: 29.056690875181832
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 29.05668313292691
#             Iterations: 40
#             Function evaluations: 309
#             Gradient evaluations: 40
# Iteration:      4,   Func. Count:     36,   Neg. LLF: 30.320529725799663
# Iteration:      8,   Func. Count:     68,   Neg. LLF: 32.37021143747794
# Iteration:     12,   Func. Count:     99,   Neg. LLF: 29.573194389081596
# Iteration:     16,   Func. Count:    127,   Neg. LLF: 29.461342583470234
# Iteration:     20,   Func. Count:    155,   Neg. LLF: 29.43192875726139
# Iteration:     24,   Func. Count:    183,   Neg. LLF: 29.359569458291062
# Iteration:     28,   Func. Count:    211,   Neg. LLF: 29.27851951599086
# Iteration:     32,   Func. Count:    239,   Neg. LLF: 29.264847115778295
# Iteration:     36,   Func. Count:    268,   Neg. LLF: 29.253170987924214
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 29.251365600120074
#             Iterations: 36
#             Function evaluations: 278
#             Gradient evaluations: 36
# Iteration:      4,   Func. Count:     36,   Neg. LLF: 30.14995649511005
# Iteration:      8,   Func. Count:     68,   Neg. LLF: 30.180703473929846
# Iteration:     12,   Func. Count:     99,   Neg. LLF: 29.621855823488943
# Iteration:     16,   Func. Count:    128,   Neg. LLF: 29.506379645902904
# Iteration:     20,   Func. Count:    156,   Neg. LLF: 29.482902467100946
# Iteration:     24,   Func. Count:    184,   Neg. LLF: 29.379088324917813
# Iteration:     28,   Func. Count:    212,   Neg. LLF: 29.326466731141135
# Iteration:     32,   Func. Count:    240,   Neg. LLF: 29.31187156753526
# Iteration:     36,   Func. Count:    268,   Neg. LLF: 29.308196410550345
# Iteration:     40,   Func. Count:    298,   Neg. LLF: 29.305094130297014
# Iteration:     44,   Func. Count:    325,   Neg. LLF: 29.304636193991662
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 29.304636193991705
#             Iterations: 44
#             Function evaluations: 325
#             Gradient evaluations: 44
# Iteration:      4,   Func. Count:     36,   Neg. LLF: 29.48604973667069
# Iteration:      8,   Func. Count:     65,   Neg. LLF: 29.303165581843608
# Iteration:     12,   Func. Count:     93,   Neg. LLF: 29.253855005858185
# Iteration:     16,   Func. Count:    122,   Neg. LLF: 29.101121029582238
# Iteration:     20,   Func. Count:    150,   Neg. LLF: 29.09186659655086
# Iteration:     24,   Func. Count:    178,   Neg. LLF: 29.05266726975704
# Iteration:     28,   Func. Count:    206,   Neg. LLF: 29.04493871245975
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 29.044628248418437
#             Iterations: 28
#             Function evaluations: 216
#             Gradient evaluations: 28
# Iteration:      4,   Func. Count:     36,   Neg. LLF: 28.948348381289005
# Iteration:      8,   Func. Count:     65,   Neg. LLF: 28.879869318516807
# Iteration:     12,   Func. Count:     93,   Neg. LLF: 28.796915124949223
# Iteration:     16,   Func. Count:    121,   Neg. LLF: 28.72513250969888
# Iteration:     20,   Func. Count:    149,   Neg. LLF: 28.70954493878277
# Iteration:     24,   Func. Count:    183,   Neg. LLF: 28.707643602833155
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 28.707488516414312
#             Iterations: 24
#             Function evaluations: 193
#             Gradient evaluations: 24
# Iteration:      4,   Func. Count:     36,   Neg. LLF: 29.147929467207344
# Iteration:      8,   Func. Count:     65,   Neg. LLF: 29.020608660616155
# Iteration:     12,   Func. Count:     94,   Neg. LLF: 28.928704994654538
# Iteration:     16,   Func. Count:    122,   Neg. LLF: 28.841047727185344
# Iteration:     20,   Func. Count:    150,   Neg. LLF: 28.823939476579014
# Iteration:     24,   Func. Count:    180,   Neg. LLF: 28.82224121762025
# Iteration:     28,   Func. Count:    211,   Neg. LLF: 28.821875335246027
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 28.82183736790936
#             Iterations: 31
#             Function evaluations: 244
#             Gradient evaluations: 31
# Iteration:      4,   Func. Count:     37,   Neg. LLF: 28.714109728788912
# Iteration:      8,   Func. Count:     66,   Neg. LLF: 28.689662543565657
# Iteration:     12,   Func. Count:     94,   Neg. LLF: 28.596740150522606
# Iteration:     16,   Func. Count:    122,   Neg. LLF: 28.539702994957363
# Iteration:     20,   Func. Count:    150,   Neg. LLF: 28.53032208442385
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 28.53024929094877
#             Iterations: 20
#             Function evaluations: 160
#             Gradient evaluations: 20
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 28.20182617009631
# Iteration:      8,   Func. Count:     63,   Neg. LLF: 28.184786761701282
# Iteration:     12,   Func. Count:     91,   Neg. LLF: 28.157832700024652
# Iteration:     16,   Func. Count:    119,   Neg. LLF: 28.05992918533009
# Iteration:     20,   Func. Count:    148,   Neg. LLF: 28.040461263545385
# Iteration:     24,   Func. Count:    176,   Neg. LLF: 28.03746098837207
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 28.037460607760263
#             Iterations: 25
#             Function evaluations: 185
#             Gradient evaluations: 25
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 27.587906707449417
# Iteration:      8,   Func. Count:     63,   Neg. LLF: 27.580875843233688
# Iteration:     12,   Func. Count:     91,   Neg. LLF: 27.543859142139222
# Iteration:     16,   Func. Count:    119,   Neg. LLF: 27.541224479440373
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 27.541197963743798
#             Iterations: 18
#             Function evaluations: 134
#             Gradient evaluations: 18
# Iteration:      4,   Func. Count:     36,   Neg. LLF: 26.942534381977985
# Iteration:      8,   Func. Count:     64,   Neg. LLF: 26.938065039290613
# Iteration:     12,   Func. Count:     92,   Neg. LLF: 26.905505583296996
# Iteration:     16,   Func. Count:    120,   Neg. LLF: 26.902812485087935
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 26.902809841843236
#             Iterations: 18
#             Function evaluations: 134
#             Gradient evaluations: 18
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 26.287905474628655
# Iteration:      8,   Func. Count:     63,   Neg. LLF: 26.279703584894186
# Iteration:     12,   Func. Count:     91,   Neg. LLF: 26.254824525470735
# Iteration:     16,   Func. Count:    119,   Neg. LLF: 26.25333614516139
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 26.25333614516139
#             Iterations: 17
#             Function evaluations: 125
#             Gradient evaluations: 17
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 25.657527073891156
# Iteration:      8,   Func. Count:     63,   Neg. LLF: 25.65142403556135
# Iteration:     12,   Func. Count:     91,   Neg. LLF: 25.62017107210285
# Iteration:     16,   Func. Count:    119,   Neg. LLF: 25.618215808568138
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 25.618215106677663
#             Iterations: 17
#             Function evaluations: 126
#             Gradient evaluations: 17
# Iteration:      4,   Func. Count:     34,   Neg. LLF: 24.95640516060242
# Iteration:      8,   Func. Count:     64,   Neg. LLF: 24.932952899862542
# Iteration:     12,   Func. Count:     92,   Neg. LLF: 24.906571382022392
# Iteration:     16,   Func. Count:    120,   Neg. LLF: 24.905843196599164
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 24.90584309025712
#             Iterations: 17
#             Function evaluations: 128
#             Gradient evaluations: 17
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 24.290397475421422
# Iteration:      8,   Func. Count:     63,   Neg. LLF: 24.28613682647534
# Iteration:     12,   Func. Count:     91,   Neg. LLF: 24.261142184836707
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 24.26100233317747
#             Iterations: 15
#             Function evaluations: 111
#             Gradient evaluations: 15
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 24.04854194584293
# Iteration:      8,   Func. Count:     64,   Neg. LLF: 23.951582048447502
# Iteration:     12,   Func. Count:     92,   Neg. LLF: 23.93967218401989
# Iteration:     16,   Func. Count:    120,   Neg. LLF: 23.922184829840322
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 23.922145407601406
#             Iterations: 19
#             Function evaluations: 141
#             Gradient evaluations: 19
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 23.260189277815204
# Iteration:      8,   Func. Count:     64,   Neg. LLF: 23.09847178202132
# Iteration:     12,   Func. Count:     92,   Neg. LLF: 23.08850987955972
# Iteration:     16,   Func. Count:    120,   Neg. LLF: 23.080107201678423
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 23.080103642422202
#             Iterations: 18
#             Function evaluations: 133
#             Gradient evaluations: 18
# Iteration:      4,   Func. Count:     36,   Neg. LLF: 25.4039295377278
# Iteration:      8,   Func. Count:     64,   Neg. LLF: 25.398028266749158
# Iteration:     12,   Func. Count:     92,   Neg. LLF: 25.397302813863988
# Iteration:     16,   Func. Count:    119,   Neg. LLF: 25.397110773160865
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 25.397110773160925
#             Iterations: 16
#             Function evaluations: 119
#             Gradient evaluations: 16
# Iteration:      4,   Func. Count:     37,   Neg. LLF: 26.664997253489435
# Iteration:      8,   Func. Count:     67,   Neg. LLF: 26.640803179374554
# Iteration:     12,   Func. Count:     95,   Neg. LLF: 26.632351628061866
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 26.632174220738005
#             Iterations: 15
#             Function evaluations: 115
#             Gradient evaluations: 15
# Iteration:      4,   Func. Count:     37,   Neg. LLF: 27.597697991661654
# Iteration:      8,   Func. Count:     66,   Neg. LLF: 27.15873056356239
# Iteration:     12,   Func. Count:     94,   Neg. LLF: 27.14637237110198
# Iteration:     16,   Func. Count:    122,   Neg. LLF: 27.132846348565636
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 27.132827516131194
#             Iterations: 19
#             Function evaluations: 143
#             Gradient evaluations: 19
# Iteration:      4,   Func. Count:     37,   Neg. LLF: 27.138179952055403
# Iteration:      8,   Func. Count:     65,   Neg. LLF: 27.03084686835329
# Iteration:     12,   Func. Count:     93,   Neg. LLF: 27.02869577500003
# Iteration:     16,   Func. Count:    121,   Neg. LLF: 27.02068626443316
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 27.020675444465997
#             Iterations: 18
#             Function evaluations: 134
#             Gradient evaluations: 18
# Iteration:      4,   Func. Count:     36,   Neg. LLF: 26.701177395316968
# Iteration:      8,   Func. Count:     64,   Neg. LLF: 26.69824999855558
# Iteration:     12,   Func. Count:     92,   Neg. LLF: 26.698155976439786
# Iteration:     16,   Func. Count:    119,   Neg. LLF: 26.69808845105749
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 26.69808845105713
#             Iterations: 16
#             Function evaluations: 119
#             Gradient evaluations: 16
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 26.20205771823593
# Iteration:      8,   Func. Count:     63,   Neg. LLF: 26.198591449295172
# Iteration:     12,   Func. Count:     91,   Neg. LLF: 26.19602147384571
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 26.19602147384571
#             Iterations: 13
#             Function evaluations: 97
#             Gradient evaluations: 13
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 26.28103430149269
# Iteration:      8,   Func. Count:     63,   Neg. LLF: 26.27284787296595
# Iteration:     12,   Func. Count:     91,   Neg. LLF: 26.272739838874067
# Iteration:     16,   Func. Count:    119,   Neg. LLF: 26.272613932671643
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 26.272613932671643
#             Iterations: 16
#             Function evaluations: 119
#             Gradient evaluations: 16
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 26.098274744668068
# Iteration:      8,   Func. Count:     63,   Neg. LLF: 26.07909098928837
# Iteration:     12,   Func. Count:     91,   Neg. LLF: 26.07869183554948
# Iteration:     16,   Func. Count:    119,   Neg. LLF: 26.07821158563107
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 26.07821158563107
#             Iterations: 17
#             Function evaluations: 125
#             Gradient evaluations: 17
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 25.666295477036222
# Iteration:      8,   Func. Count:     63,   Neg. LLF: 25.57771754862567
# Iteration:     12,   Func. Count:     91,   Neg. LLF: 25.574835122616875
# Iteration:     16,   Func. Count:    118,   Neg. LLF: 25.571509753372794
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 25.571509753372
#             Iterations: 16
#             Function evaluations: 118
#             Gradient evaluations: 16
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 42.05241089260486
# Iteration:      8,   Func. Count:     66,   Neg. LLF: 30.212236251644466
# Iteration:     12,   Func. Count:     95,   Neg. LLF: 30.16462009665692
# Iteration:     16,   Func. Count:    123,   Neg. LLF: 30.065273498161147
# Iteration:     20,   Func. Count:    153,   Neg. LLF: 30.030488856966937
# Iteration:     24,   Func. Count:    181,   Neg. LLF: 30.029768918247225
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 30.029766687687392
#             Iterations: 26
#             Function evaluations: 194
#             Gradient evaluations: 26
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 47.85886568362353
# Iteration:      8,   Func. Count:     66,   Neg. LLF: 30.341007963832922
# Iteration:     12,   Func. Count:     95,   Neg. LLF: 30.286939022607122
# Iteration:     16,   Func. Count:    123,   Neg. LLF: 30.188775502604123
# Iteration:     20,   Func. Count:    153,   Neg. LLF: 30.15902883719956
# Iteration:     24,   Func. Count:    181,   Neg. LLF: 30.15901022814885
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 30.15901022814885
#             Iterations: 25
#             Function evaluations: 187
#             Gradient evaluations: 25
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 33.89549612954348
# Iteration:      8,   Func. Count:     67,   Neg. LLF: 33.81227844053437
# Iteration:     12,   Func. Count:     95,   Neg. LLF: 33.700149115760865
# Iteration:     16,   Func. Count:    124,   Neg. LLF: 33.57679534439766
# Iteration:     20,   Func. Count:    151,   Neg. LLF: 33.57672141323512
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 33.57672141323533
#             Iterations: 20
#             Function evaluations: 151
#             Gradient evaluations: 20
# Iteration:      4,   Func. Count:     37,   Neg. LLF: 35.17687252734188
# Iteration:      8,   Func. Count:     66,   Neg. LLF: 34.894664669364296
# Iteration:     12,   Func. Count:     94,   Neg. LLF: 34.75353168525494
# Iteration:     16,   Func. Count:    123,   Neg. LLF: 34.69487474199274
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 34.6948569392505
#             Iterations: 19
#             Function evaluations: 143
#             Gradient evaluations: 19
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 35.41476954362764
# Iteration:      8,   Func. Count:     67,   Neg. LLF: 35.372242802093666
# Iteration:     12,   Func. Count:     97,   Neg. LLF: 133.42268523843512
# Iteration:     16,   Func. Count:    128,   Neg. LLF: 35.133011316930975
# Iteration:     20,   Func. Count:    156,   Neg. LLF: 35.12702921234493
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 35.12702770826056
#             Iterations: 22
#             Function evaluations: 169
#             Gradient evaluations: 22
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 35.87583880414498
# Iteration:      8,   Func. Count:     67,   Neg. LLF: 35.49183712132461
# Iteration:     12,   Func. Count:     96,   Neg. LLF: 35.22131150346101
# Iteration:     16,   Func. Count:    124,   Neg. LLF: 35.21691997497053
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 35.21691930007568
#             Iterations: 17
#             Function evaluations: 131
#             Gradient evaluations: 17
# Iteration:      4,   Func. Count:     37,   Neg. LLF: 36.05959862771387
# Iteration:      8,   Func. Count:     66,   Neg. LLF: 35.70575414406883
# Iteration:     12,   Func. Count:     97,   Neg. LLF: 35.58108075585407
# Iteration:     16,   Func. Count:    125,   Neg. LLF: 35.44168288210675
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 35.44166126424901
#             Iterations: 19
#             Function evaluations: 145
#             Gradient evaluations: 19
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 37.95264953606516
# Iteration:      8,   Func. Count:     67,   Neg. LLF: 37.91974239407523
# Iteration:     12,   Func. Count:     97,   Neg. LLF: 142.0234359754121
# Iteration:     16,   Func. Count:    128,   Neg. LLF: 37.73137694637579
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 37.73132790293185
#             Iterations: 19
#             Function evaluations: 148
#             Gradient evaluations: 19
# Iteration:      4,   Func. Count:     37,   Neg. LLF: 38.94744760384561
# Iteration:      8,   Func. Count:     66,   Neg. LLF: 38.88633990692985
# Iteration:     12,   Func. Count:     95,   Neg. LLF: 38.99906336693872
# Iteration:     16,   Func. Count:    124,   Neg. LLF: 38.71639198186619
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 38.71637172261438
#             Iterations: 19
#             Function evaluations: 144
#             Gradient evaluations: 19
# Iteration:      4,   Func. Count:     36,   Neg. LLF: 39.29852538256834
# Iteration:      8,   Func. Count:     66,   Neg. LLF: 39.10941130206783
# Iteration:     12,   Func. Count:     96,   Neg. LLF: 39.594429920203346
# Iteration:     16,   Func. Count:    125,   Neg. LLF: 38.897839549231804
# Iteration:     20,   Func. Count:    152,   Neg. LLF: 38.89775540682554
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 38.89775540682558
#             Iterations: 20
#             Function evaluations: 152
#             Gradient evaluations: 20
# Iteration:      4,   Func. Count:     36,   Neg. LLF: 39.7504575712566
# Iteration:      8,   Func. Count:     65,   Neg. LLF: 39.426727974820444
# Iteration:     12,   Func. Count:     93,   Neg. LLF: 39.270967642142054
# Iteration:     16,   Func. Count:    122,   Neg. LLF: 39.20567211351476
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 39.20567115498072
#             Iterations: 17
#             Function evaluations: 129
#             Gradient evaluations: 17
# Iteration:      4,   Func. Count:     36,   Neg. LLF: 39.53806476646829
# Iteration:      8,   Func. Count:     66,   Neg. LLF: 39.34780362531146
# Iteration:     12,   Func. Count:     94,   Neg. LLF: 39.14808288393394
# Iteration:     16,   Func. Count:    124,   Neg. LLF: 39.06156605399832
# Iteration:     20,   Func. Count:    151,   Neg. LLF: 39.06039286580183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 39.06039286580257
#             Iterations: 20
#             Function evaluations: 151
#             Gradient evaluations: 20
# Iteration:      4,   Func. Count:     36,   Neg. LLF: 39.435378171409276
# Iteration:      8,   Func. Count:     65,   Neg. LLF: 39.16866058937553
# Iteration:     12,   Func. Count:     95,   Neg. LLF: 39.24863116491749
# Iteration:     16,   Func. Count:    124,   Neg. LLF: 38.790913470270354
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 38.790813487963284
#             Iterations: 19
#             Function evaluations: 144
#             Gradient evaluations: 19
# Iteration:      4,   Func. Count:     36,   Neg. LLF: 39.42958984625423
# Iteration:      8,   Func. Count:     65,   Neg. LLF: 39.181901028212636
# Iteration:     12,   Func. Count:     95,   Neg. LLF: 150.99308224609885
# Iteration:     16,   Func. Count:    126,   Neg. LLF: 38.818686804833035
# Iteration:     20,   Func. Count:    154,   Neg. LLF: 38.79598446156652
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 38.79598446156652
#             Iterations: 21
#             Function evaluations: 160
#             Gradient evaluations: 21
# Iteration:      4,   Func. Count:     36,   Neg. LLF: 39.35908992454551
# Iteration:      8,   Func. Count:     66,   Neg. LLF: 39.02617656231112
# Iteration:     12,   Func. Count:     96,   Neg. LLF: 152.19561010028664
# Iteration:     16,   Func. Count:    127,   Neg. LLF: 38.64317111181108
# Iteration:     20,   Func. Count:    155,   Neg. LLF: 38.616280856690366
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 38.616276774914056
#             Iterations: 22
#             Function evaluations: 168
#             Gradient evaluations: 22
# Iteration:      4,   Func. Count:     37,   Neg. LLF: 38.97037422028094
# Iteration:      8,   Func. Count:     66,   Neg. LLF: 38.66768544547712
# Iteration:     12,   Func. Count:     97,   Neg. LLF: 38.670094892851665
# Iteration:     16,   Func. Count:    126,   Neg. LLF: 38.340303174263674
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 38.34028735753582
#             Iterations: 18
#             Function evaluations: 139
#             Gradient evaluations: 18
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 43.539189274491996
# Iteration:      8,   Func. Count:     64,   Neg. LLF: 43.16868886507747
# Iteration:     12,   Func. Count:     93,   Neg. LLF: 42.56177252321487
# Iteration:     16,   Func. Count:    122,   Neg. LLF: 42.45974081460282
# Iteration:     20,   Func. Count:    150,   Neg. LLF: 42.4398279432853
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 42.43977965506956
#             Iterations: 23
#             Function evaluations: 170
#             Gradient evaluations: 23
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 297.7742815587062
# Iteration:      8,   Func. Count:     67,   Neg. LLF: 46.42868880042195
# Iteration:     12,   Func. Count:     95,   Neg. LLF: 157.1273042286663
# Iteration:     16,   Func. Count:    127,   Neg. LLF: 103.46547615311952
# Iteration:     20,   Func. Count:    158,   Neg. LLF: 45.4232747738414
# Iteration:     24,   Func. Count:    186,   Neg. LLF: 45.37875817819981
# Iteration:     28,   Func. Count:    214,   Neg. LLF: 45.36027475944429
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 45.360268610161185
#             Iterations: 30
#             Function evaluations: 228
#             Gradient evaluations: 30
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 94.67920871522755
# Iteration:      8,   Func. Count:     65,   Neg. LLF: 47.71510805696665
# Iteration:     12,   Func. Count:     96,   Neg. LLF: 155.29693889919915
# Iteration:     16,   Func. Count:    127,   Neg. LLF: 47.218642005542236
# Iteration:     20,   Func. Count:    155,   Neg. LLF: 47.186422221376276
# Iteration:     24,   Func. Count:    183,   Neg. LLF: 47.14646822331751
# Iteration:     28,   Func. Count:    211,   Neg. LLF: 47.1457200862518
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 47.1457200862518
#             Iterations: 28
#             Function evaluations: 211
#             Gradient evaluations: 28
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 198.91788670141494
# Iteration:      8,   Func. Count:     66,   Neg. LLF: 48.924064763508554
# Iteration:     12,   Func. Count:     95,   Neg. LLF: 158.25120908762156
# Iteration:     16,   Func. Count:    126,   Neg. LLF: 47.9730927956568
# Iteration:     20,   Func. Count:    154,   Neg. LLF: 47.95458001885566
# Iteration:     24,   Func. Count:    182,   Neg. LLF: 47.94032102187674
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 47.940229246593525
#             Iterations: 27
#             Function evaluations: 203
#             Gradient evaluations: 27
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 196.65616418038414
# Iteration:      8,   Func. Count:     66,   Neg. LLF: 49.14003615700125
# Iteration:     12,   Func. Count:     96,   Neg. LLF: 160.8278900503646
# Iteration:     16,   Func. Count:    128,   Neg. LLF: 170.90182837532953
# Iteration:     20,   Func. Count:    158,   Neg. LLF: 48.15900047370756
# Iteration:     24,   Func. Count:    187,   Neg. LLF: 48.122408257464905
# Iteration:     28,   Func. Count:    215,   Neg. LLF: 48.10357734853301
# Iteration:     32,   Func. Count:    243,   Neg. LLF: 48.10183816006368
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 48.10183816006368
#             Iterations: 32
#             Function evaluations: 243
#             Gradient evaluations: 32
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 200.01287224042963
# Iteration:      8,   Func. Count:     66,   Neg. LLF: 49.82175607585014
# Iteration:     12,   Func. Count:     96,   Neg. LLF: 162.57333770339764
# Iteration:     16,   Func. Count:    128,   Neg. LLF: 149.366237005187
# Iteration:     20,   Func. Count:    160,   Neg. LLF: 48.92526981425732
# Iteration:     24,   Func. Count:    188,   Neg. LLF: 48.8410275698822
# Iteration:     28,   Func. Count:    216,   Neg. LLF: 48.83891127286738
# Iteration:     32,   Func. Count:    244,   Neg. LLF: 48.82782799098154
# Iteration:     36,   Func. Count:    272,   Neg. LLF: 48.820157923430834
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 48.82015720292404
#             Iterations: 37
#             Function evaluations: 279
#             Gradient evaluations: 37
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 202.25407129399173
# Iteration:      8,   Func. Count:     67,   Neg. LLF: 50.901881497556914
# Iteration:     12,   Func. Count:     95,   Neg. LLF: 49.99753080642399
# Iteration:     16,   Func. Count:    124,   Neg. LLF: 49.95034019416989
# Iteration:     20,   Func. Count:    152,   Neg. LLF: 49.947053362909436
# Iteration:     24,   Func. Count:    180,   Neg. LLF: 49.94626271003725
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 49.94626271003725
#             Iterations: 25
#             Function evaluations: 186
#             Gradient evaluations: 25
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 406.65296376307094
# Iteration:      8,   Func. Count:     65,   Neg. LLF: 51.63450400496708
# Iteration:     12,   Func. Count:     94,   Neg. LLF: 50.90743313710319
# Iteration:     16,   Func. Count:    122,   Neg. LLF: 50.854292362842436
# Iteration:     20,   Func. Count:    150,   Neg. LLF: 50.85340842059035
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 50.85340842059035
#             Iterations: 21
#             Function evaluations: 156
#             Gradient evaluations: 21
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 204.02630804932227
# Iteration:      8,   Func. Count:     66,   Neg. LLF: 52.25712973789012
# Iteration:     12,   Func. Count:     95,   Neg. LLF: 183.77041164469745
# Iteration:     16,   Func. Count:    127,   Neg. LLF: 52.610546995289084
# Iteration:     20,   Func. Count:    157,   Neg. LLF: 51.48415739139574
# Iteration:     24,   Func. Count:    185,   Neg. LLF: 51.47030900586867
# Iteration:     28,   Func. Count:    212,   Neg. LLF: 51.46814627091752
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 51.46814627091682
#             Iterations: 28
#             Function evaluations: 212
#             Gradient evaluations: 28
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 58.877161844899064
# Iteration:      8,   Func. Count:     67,   Neg. LLF: 54.67788923385869
# Iteration:     12,   Func. Count:     97,   Neg. LLF: 181.0068942103447
# Iteration:     16,   Func. Count:    129,   Neg. LLF: 58.321362657847374
# Iteration:     20,   Func. Count:    159,   Neg. LLF: 53.876070810433816
# Iteration:     24,   Func. Count:    187,   Neg. LLF: 53.86208659676024
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 53.86208275552661
#             Iterations: 26
#             Function evaluations: 200
#             Gradient evaluations: 26
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 58.57259126142064
# Iteration:      8,   Func. Count:     65,   Neg. LLF: 55.26269378973993
# Iteration:     12,   Func. Count:     96,   Neg. LLF: 63.3210159512085
# Iteration:     16,   Func. Count:    126,   Neg. LLF: 54.4691170629396
# Iteration:     20,   Func. Count:    155,   Neg. LLF: 54.40434460257728
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 54.40429653053008
#             Iterations: 23
#             Function evaluations: 175
#             Gradient evaluations: 23
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 59.12344036967019
# Iteration:      8,   Func. Count:     66,   Neg. LLF: 55.484855934210024
# Iteration:     12,   Func. Count:     95,   Neg. LLF: 54.8786725936514
# Iteration:     16,   Func. Count:    124,   Neg. LLF: 54.673257524253195
# Iteration:     20,   Func. Count:    152,   Neg. LLF: 54.653459193562895
# Iteration:     24,   Func. Count:    179,   Neg. LLF: 54.65340500330694
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 54.65340500330514
#             Iterations: 24
#             Function evaluations: 179
#             Gradient evaluations: 24
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 58.16463651589038
# Iteration:      8,   Func. Count:     67,   Neg. LLF: 74.09435805786107
# Iteration:     12,   Func. Count:     98,   Neg. LLF: 55.418148773481214
# Iteration:     16,   Func. Count:    127,   Neg. LLF: 54.726687284535615
# Iteration:     20,   Func. Count:    155,   Neg. LLF: 54.641434083487454
# Iteration:     24,   Func. Count:    184,   Neg. LLF: 54.63139257015093
# Iteration:     28,   Func. Count:    212,   Neg. LLF: 54.62010054662673
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 54.62008847730244
#             Iterations: 30
#             Function evaluations: 225
#             Gradient evaluations: 30
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 59.37523103665322
# Iteration:      8,   Func. Count:     67,   Neg. LLF: 55.86622168192688
# Iteration:     12,   Func. Count:     96,   Neg. LLF: 66.87572956044045
# Iteration:     16,   Func. Count:    128,   Neg. LLF: 180.30817889841722
# Iteration:     20,   Func. Count:    159,   Neg. LLF: 54.93749914168452
# Iteration:     24,   Func. Count:    187,   Neg. LLF: 54.90953821929335
# Iteration:     28,   Func. Count:    215,   Neg. LLF: 54.907680349942396
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 54.907680349942396
#             Iterations: 29
#             Function evaluations: 221
#             Gradient evaluations: 29
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 58.17193822625815
# Iteration:      8,   Func. Count:     67,   Neg. LLF: 59.57070165551138
# Iteration:     12,   Func. Count:     97,   Neg. LLF: 56.16286146497684
# Iteration:     16,   Func. Count:    128,   Neg. LLF: 181.24417384485878
# Iteration:     20,   Func. Count:    159,   Neg. LLF: 55.5512069692826
# Iteration:     24,   Func. Count:    187,   Neg. LLF: 55.532595905888684
# Iteration:     28,   Func. Count:    215,   Neg. LLF: 55.52937817069167
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 55.52933724068627
#             Iterations: 31
#             Function evaluations: 235
#             Gradient evaluations: 31
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 211.0442692268105
# Iteration:      8,   Func. Count:     67,   Neg. LLF: 56.367675012769354
# Iteration:     12,   Func. Count:     96,   Neg. LLF: 180.11000507110253
# Iteration:     16,   Func. Count:    128,   Neg. LLF: 173.41266605954053
# Iteration:     20,   Func. Count:    159,   Neg. LLF: 55.452594552028174
# Iteration:     24,   Func. Count:    187,   Neg. LLF: 55.450889246271245
# Iteration:     28,   Func. Count:    215,   Neg. LLF: 55.44485029264011
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 55.44477597189652
#             Iterations: 31
#             Function evaluations: 235
#             Gradient evaluations: 31
# ('monthly_Return', 'FIGARCH')
#                  h.1
# 2015-11-30  0.128565
# 2015-12-31  0.116443
# 2016-01-31  0.187505
# 2016-02-29  0.119208
# 2016-03-31  0.173677
# ...              ...
# 2021-01-31  0.194928
# 2021-02-28  0.149125
# 2021-03-31  0.165397
# 2021-04-30  0.193083
# 2021-05-31  0.125014
#
# [67 rows x 1 columns]
# Iteration:      4,   Func. Count:     39,   Neg. LLF: 27.367912371366305
# Iteration:      8,   Func. Count:     73,   Neg. LLF: 26.89875873388911
# Iteration:     12,   Func. Count:    105,   Neg. LLF: 26.769333962266614
# Iteration:     16,   Func. Count:    137,   Neg. LLF: 26.614782288003873
# Iteration:     20,   Func. Count:    169,   Neg. LLF: 26.551205937240127
# Iteration:     24,   Func. Count:    203,   Neg. LLF: 26.536292176244995
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 26.536158844738626
#             Iterations: 26
#             Function evaluations: 229
#             Gradient evaluations: 26
# Iteration:      4,   Func. Count:     39,   Neg. LLF: 27.601601669323273
# Iteration:      8,   Func. Count:     73,   Neg. LLF: 27.164114370247972
# Iteration:     12,   Func. Count:    105,   Neg. LLF: 27.087606543191438
# Iteration:     16,   Func. Count:    137,   Neg. LLF: 26.92192935062316
# Iteration:     20,   Func. Count:    169,   Neg. LLF: 26.866098297590618
# Iteration:     24,   Func. Count:    201,   Neg. LLF: 26.846359841228928
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 26.843445647888487
#             Iterations: 24
#             Function evaluations: 211
#             Gradient evaluations: 24
# Iteration:      4,   Func. Count:     39,   Neg. LLF: 29.146873512959324
# Iteration:      8,   Func. Count:     74,   Neg. LLF: 28.50931012354003
# Iteration:     12,   Func. Count:    106,   Neg. LLF: 28.378846888457797
# Iteration:     16,   Func. Count:    138,   Neg. LLF: 28.18244719728862
# Iteration:     20,   Func. Count:    170,   Neg. LLF: 28.12078346046027
# Iteration:     24,   Func. Count:    205,   Neg. LLF: 28.112668873591435
# Iteration:     28,   Func. Count:    238,   Neg. LLF: 28.111936478559354
# Iteration:     32,   Func. Count:    273,   Neg. LLF: 28.11187459355415
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 28.11185171169913
#             Iterations: 35
#             Function evaluations: 308
#             Gradient evaluations: 35
# Iteration:      4,   Func. Count:     39,   Neg. LLF: 29.323720417875318
# Iteration:      8,   Func. Count:     73,   Neg. LLF: 28.58892851970039
# Iteration:     12,   Func. Count:    105,   Neg. LLF: 28.441545081238868
# Iteration:     16,   Func. Count:    137,   Neg. LLF: 28.273244028615853
# Iteration:     20,   Func. Count:    169,   Neg. LLF: 28.215254266297816
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 28.200655179507375
#             Iterations: 22
#             Function evaluations: 195
#             Gradient evaluations: 22
# Iteration:      4,   Func. Count:     39,   Neg. LLF: 30.660571832367676
# Iteration:      8,   Func. Count:     73,   Neg. LLF: 29.77758515468113
# Iteration:     12,   Func. Count:    106,   Neg. LLF: 29.738445138513498
# Iteration:     16,   Func. Count:    138,   Neg. LLF: 29.459700696997476
# Iteration:     20,   Func. Count:    170,   Neg. LLF: 29.339984219979097
# Iteration:     24,   Func. Count:    203,   Neg. LLF: 29.3004523152493
# Iteration:     28,   Func. Count:    240,   Neg. LLF: 29.295760869666427
# Iteration:     32,   Func. Count:    276,   Neg. LLF: 29.2957474960274
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 29.295745689084484
#             Iterations: 32
#             Function evaluations: 286
#             Gradient evaluations: 32
# Iteration:      4,   Func. Count:     39,   Neg. LLF: 30.726779958575392
# Iteration:      8,   Func. Count:     73,   Neg. LLF: 29.84900512775338
# Iteration:     12,   Func. Count:    105,   Neg. LLF: 29.688967307099517
# Iteration:     16,   Func. Count:    137,   Neg. LLF: 29.433897918979277
# Iteration:     20,   Func. Count:    169,   Neg. LLF: 29.343148791385303
# Iteration:     24,   Func. Count:    201,   Neg. LLF: 29.318093039516487
# Iteration:     28,   Func. Count:    263,   Neg. LLF: 29.317854447726624
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 29.317770637347508
#             Iterations: 31
#             Function evaluations: 299
#             Gradient evaluations: 31
# Iteration:      4,   Func. Count:     40,   Neg. LLF: 30.457912354106643
# Iteration:      8,   Func. Count:     75,   Neg. LLF: 29.577618345716598
# Iteration:     12,   Func. Count:    107,   Neg. LLF: 29.534319575711628
# Iteration:     16,   Func. Count:    139,   Neg. LLF: 29.31353057658982
# Iteration:     20,   Func. Count:    171,   Neg. LLF: 29.233687270964282
# Iteration:     24,   Func. Count:    203,   Neg. LLF: 29.310396210115176
# Iteration:     28,   Func. Count:    238,   Neg. LLF: 29.201132963304637
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 29.198565588235358
#             Iterations: 29
#             Function evaluations: 257
#             Gradient evaluations: 29
# Iteration:      4,   Func. Count:     39,   Neg. LLF: 30.125228747525558
# Iteration:      8,   Func. Count:     73,   Neg. LLF: 29.43782937728639
# Iteration:     12,   Func. Count:    106,   Neg. LLF: 29.413918420544526
# Iteration:     16,   Func. Count:    138,   Neg. LLF: 29.300838903163267
# Iteration:     20,   Func. Count:    170,   Neg. LLF: 29.16704658930544
# Iteration:     24,   Func. Count:    203,   Neg. LLF: 29.109310667617272
# Iteration:     28,   Func. Count:    235,   Neg. LLF: 29.107977521848003
# Iteration:     32,   Func. Count:    268,   Neg. LLF: 29.1444766287057
# ...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 37.19592929612282
#             Iterations: 21
#             Function evaluations: 180
#             Gradient evaluations: 21
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 64.43564676324559
# Iteration:      8,   Func. Count:     77,   Neg. LLF: 38.20165214825726
# Iteration:     12,   Func. Count:    109,   Neg. LLF: 38.19667640014011
# Iteration:     16,   Func. Count:    141,   Neg. LLF: 38.1942332754951
# Iteration:     20,   Func. Count:    175,   Neg. LLF: 38.18941921876443
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 38.18941492939483
#             Iterations: 22
#             Function evaluations: 191
#             Gradient evaluations: 22
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 56.99773739475599
# Iteration:      8,   Func. Count:     77,   Neg. LLF: 38.49889763232565
# Iteration:     12,   Func. Count:    108,   Neg. LLF: 38.49510443657483
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 38.495104436566606
#             Iterations: 12
#             Function evaluations: 108
#             Gradient evaluations: 12
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 56.11436777735975
# Iteration:      8,   Func. Count:     77,   Neg. LLF: 38.76679296595065
# Iteration:     12,   Func. Count:    109,   Neg. LLF: 38.763624028788946
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 38.763624028788946
#             Iterations: 12
#             Function evaluations: 109
#             Gradient evaluations: 12
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 57.09011905700912
# Iteration:      8,   Func. Count:     77,   Neg. LLF: 38.60936948484352
# Iteration:     12,   Func. Count:    109,   Neg. LLF: 38.60641950793848
# Iteration:     16,   Func. Count:    141,   Neg. LLF: 38.60427918590579
# Iteration:     20,   Func. Count:    172,   Neg. LLF: 38.6031748913269
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 38.603174891326766
#             Iterations: 20
#             Function evaluations: 172
#             Gradient evaluations: 20
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 58.716555039768714
# Iteration:      8,   Func. Count:     77,   Neg. LLF: 38.34557029058695
# Iteration:     12,   Func. Count:    109,   Neg. LLF: 38.34168016040405
# Iteration:     16,   Func. Count:    141,   Neg. LLF: 38.32552176337997
# Iteration:     20,   Func. Count:    174,   Neg. LLF: 38.320136785930316
# Iteration:     24,   Func. Count:    209,   Neg. LLF: 38.320219856531416
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 38.320127115716176
#             Iterations: 26
#             Function evaluations: 229
#             Gradient evaluations: 26
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 56.947368627955804
# Iteration:      8,   Func. Count:     77,   Neg. LLF: 38.343820682482544
# Iteration:     12,   Func. Count:    109,   Neg. LLF: 38.33929580623106
# Iteration:     16,   Func. Count:    141,   Neg. LLF: 38.31956215374697
# Iteration:     20,   Func. Count:    173,   Neg. LLF: 38.31914474548749
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 38.319143391387776
#             Iterations: 22
#             Function evaluations: 188
#             Gradient evaluations: 22
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 56.894159986277884
# Iteration:      8,   Func. Count:     77,   Neg. LLF: 38.17292499095149
# Iteration:     12,   Func. Count:    109,   Neg. LLF: 38.16857733287377
# Iteration:     16,   Func. Count:    141,   Neg. LLF: 38.14525189999177
# Iteration:     20,   Func. Count:    174,   Neg. LLF: 38.13538933031466
# Iteration:     24,   Func. Count:    208,   Neg. LLF: 38.13560095405335
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 38.13527944139169
#             Iterations: 26
#             Function evaluations: 228
#             Gradient evaluations: 26
# Iteration:      4,   Func. Count:     40,   Neg. LLF: 57.42409933953975
# Iteration:      8,   Func. Count:     76,   Neg. LLF: 37.91510691614805
# Iteration:     12,   Func. Count:    108,   Neg. LLF: 37.89878085533069
# Iteration:     16,   Func. Count:    140,   Neg. LLF: 37.86188922758044
# Iteration:     20,   Func. Count:    172,   Neg. LLF: 37.85630518546192
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 37.85630498644422
#             Iterations: 21
#             Function evaluations: 181
#             Gradient evaluations: 21
# Iteration:      4,   Func. Count:     40,   Neg. LLF: 67.30235987753396
# Iteration:      8,   Func. Count:     76,   Neg. LLF: 42.48943984116734
# Iteration:     12,   Func. Count:    108,   Neg. LLF: 42.42996281563837
# Iteration:     16,   Func. Count:    142,   Neg. LLF: 43.21511995131563
# Iteration:     20,   Func. Count:    176,   Neg. LLF: 42.161615384210904
# Iteration:     24,   Func. Count:    208,   Neg. LLF: 42.15880496302324
# Iteration:     28,   Func. Count:    244,   Neg. LLF: 42.15835297914189
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 42.15835026111788
#             Iterations: 30
#             Function evaluations: 261
#             Gradient evaluations: 30
# Iteration:      4,   Func. Count:     42,   Neg. LLF: 167.6887601503099
# Iteration:      8,   Func. Count:     77,   Neg. LLF: 45.3932673122897
# Iteration:     12,   Func. Count:    110,   Neg. LLF: 45.112531586912375
# Iteration:     16,   Func. Count:    142,   Neg. LLF: 44.91385593281193
# Iteration:     20,   Func. Count:    174,   Neg. LLF: 44.85056291170777
# Iteration:     24,   Func. Count:    206,   Neg. LLF: 44.83668354483139
# Iteration:     28,   Func. Count:    238,   Neg. LLF: 44.83406853351122
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 44.83406624152115
#             Iterations: 30
#             Function evaluations: 253
#             Gradient evaluations: 30
# Iteration:      4,   Func. Count:     42,   Neg. LLF: 272.11138543901023
# Iteration:      8,   Func. Count:     77,   Neg. LLF: 46.928207532197675
# Iteration:     12,   Func. Count:    109,   Neg. LLF: 46.815764514037376
# Iteration:     16,   Func. Count:    142,   Neg. LLF: 46.606512073161234
# Iteration:     20,   Func. Count:    174,   Neg. LLF: 46.57567771345757
# Iteration:     24,   Func. Count:    206,   Neg. LLF: 46.57260200953563
# Iteration:     28,   Func. Count:    237,   Neg. LLF: 46.572500577710294
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 46.572500577710215
#             Iterations: 28
#             Function evaluations: 237
#             Gradient evaluations: 28
# Iteration:      4,   Func. Count:     42,   Neg. LLF: 239.45566642951957
# Iteration:      8,   Func. Count:     76,   Neg. LLF: 47.61208815559428
# Iteration:     12,   Func. Count:    108,   Neg. LLF: 47.479824627747384
# Iteration:     16,   Func. Count:    140,   Neg. LLF: 47.25103225327133
# Iteration:     20,   Func. Count:    173,   Neg. LLF: 47.22333325496574
# Iteration:     24,   Func. Count:    205,   Neg. LLF: 47.205468767268606
# Iteration:     28,   Func. Count:    236,   Neg. LLF: 47.2048799148729
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 47.20487991487285
#             Iterations: 28
#             Function evaluations: 236
#             Gradient evaluations: 28
# Iteration:      4,   Func. Count:     42,   Neg. LLF: 339.954003486456
# Iteration:      8,   Func. Count:     76,   Neg. LLF: 47.733084554422824
# Iteration:     12,   Func. Count:    109,   Neg. LLF: 47.50035612526622
# Iteration:     16,   Func. Count:    143,   Neg. LLF: 47.5345499820308
# Iteration:     20,   Func. Count:    176,   Neg. LLF: 47.24229644203037
# Iteration:     24,   Func. Count:    208,   Neg. LLF: 47.198861227032815
# Iteration:     28,   Func. Count:    240,   Neg. LLF: 47.19531339950135
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 47.19531339950135
#             Iterations: 29
#             Function evaluations: 247
#             Gradient evaluations: 29
# Iteration:      4,   Func. Count:     42,   Neg. LLF: 465.01553232116305
# Iteration:      8,   Func. Count:     77,   Neg. LLF: 48.907020676009225
# Iteration:     12,   Func. Count:    110,   Neg. LLF: 48.41801475977123
# Iteration:     16,   Func. Count:    142,   Neg. LLF: 48.255377711957216
# Iteration:     20,   Func. Count:    174,   Neg. LLF: 48.18565723602634
# Iteration:     24,   Func. Count:    206,   Neg. LLF: 48.166655346638784
# Iteration:     28,   Func. Count:    237,   Neg. LLF: 48.166368654887336
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 48.16636865489099
#             Iterations: 28
#             Function evaluations: 237
#             Gradient evaluations: 28
# Iteration:      4,   Func. Count:     42,   Neg. LLF: 208.32716982111663
# Iteration:      8,   Func. Count:     76,   Neg. LLF: 49.92524261916273
# Iteration:     12,   Func. Count:    109,   Neg. LLF: 49.719881397151035
# Iteration:     16,   Func. Count:    141,   Neg. LLF: 49.453596722498894
# Iteration:     20,   Func. Count:    173,   Neg. LLF: 49.44884555381923
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 49.44878839500463
#             Iterations: 21
#             Function evaluations: 184
#             Gradient evaluations: 21
# Iteration:      4,   Func. Count:     42,   Neg. LLF: 196.7957629026836
# Iteration:      8,   Func. Count:     76,   Neg. LLF: 50.71882782012603
# Iteration:     12,   Func. Count:    108,   Neg. LLF: 50.53978343335548
# Iteration:     16,   Func. Count:    140,   Neg. LLF: 50.332059353773566
# Iteration:     20,   Func. Count:    172,   Neg. LLF: 50.31105776370504
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 50.311049255939636
#             Iterations: 22
#             Function evaluations: 187
#             Gradient evaluations: 22
# Iteration:      4,   Func. Count:     42,   Neg. LLF: 110.02522013028658
# Iteration:      8,   Func. Count:     76,   Neg. LLF: 51.21990404954808
# Iteration:     12,   Func. Count:    109,   Neg. LLF: 51.063645046672235
# Iteration:     16,   Func. Count:    141,   Neg. LLF: 50.959603659459766
# Iteration:     20,   Func. Count:    173,   Neg. LLF: 50.89419232818881
# Iteration:     24,   Func. Count:    205,   Neg. LLF: 50.891150672630104
# Iteration:     28,   Func. Count:    237,   Neg. LLF: 50.8898715193285
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 50.889870053348396
#             Iterations: 30
#             Function evaluations: 252
#             Gradient evaluations: 30
# Iteration:      4,   Func. Count:     43,   Neg. LLF: 142.25803640310443
# Iteration:      8,   Func. Count:     78,   Neg. LLF: 53.786405186759225
# Iteration:     12,   Func. Count:    110,   Neg. LLF: 53.636504449036366
# Iteration:     16,   Func. Count:    142,   Neg. LLF: 53.503660181141825
# Iteration:     20,   Func. Count:    174,   Neg. LLF: 53.43870211762835
# Iteration:     24,   Func. Count:    206,   Neg. LLF: 53.437892564046294
# Iteration:     28,   Func. Count:    238,   Neg. LLF: 53.437547762670526
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 53.437546777513475
#             Iterations: 29
#             Function evaluations: 246
#             Gradient evaluations: 29
# Iteration:      4,   Func. Count:     43,   Neg. LLF: 101.9538965827064
# Iteration:      8,   Func. Count:     77,   Neg. LLF: 54.262189003427565
# Iteration:     12,   Func. Count:    109,   Neg. LLF: 54.14863379785902
# Iteration:     16,   Func. Count:    141,   Neg. LLF: 54.018910514078065
# Iteration:     20,   Func. Count:    173,   Neg. LLF: 53.95650779737986
# Iteration:     24,   Func. Count:    205,   Neg. LLF: 53.95011695519591
# Iteration:     28,   Func. Count:    236,   Neg. LLF: 53.949780181519316
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 53.94978018151739
#             Iterations: 28
#             Function evaluations: 236
#             Gradient evaluations: 28
# Iteration:      4,   Func. Count:     43,   Neg. LLF: 131.53565711889607
# Iteration:      8,   Func. Count:     78,   Neg. LLF: 54.60908539576192
# Iteration:     12,   Func. Count:    110,   Neg. LLF: 54.42834537181245
# Iteration:     16,   Func. Count:    142,   Neg. LLF: 54.32625640940924
# Iteration:     20,   Func. Count:    174,   Neg. LLF: 54.24050953639121
# Iteration:     24,   Func. Count:    206,   Neg. LLF: 54.231564441466865
# Iteration:     28,   Func. Count:    237,   Neg. LLF: 54.23090657967404
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 54.23090657967485
#             Iterations: 28
#             Function evaluations: 237
#             Gradient evaluations: 28
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 172.066670723178
# Iteration:      8,   Func. Count:     76,   Neg. LLF: 54.63660492043813
# Iteration:     12,   Func. Count:    108,   Neg. LLF: 54.358066968780385
# Iteration:     16,   Func. Count:    140,   Neg. LLF: 54.12602090874071
# Iteration:     20,   Func. Count:    172,   Neg. LLF: 54.10951335333306
# Iteration:     24,   Func. Count:    204,   Neg. LLF: 54.10930236221658
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 54.10929740328153
#             Iterations: 26
#             Function evaluations: 219
#             Gradient evaluations: 26
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 177.54159360038994
# Iteration:      8,   Func. Count:     76,   Neg. LLF: 54.92731518483008
# Iteration:     12,   Func. Count:    108,   Neg. LLF: 54.64196251224165
# Iteration:     16,   Func. Count:    140,   Neg. LLF: 54.430244497147626
# Iteration:     20,   Func. Count:    172,   Neg. LLF: 54.407773392403726
# Iteration:     24,   Func. Count:    204,   Neg. LLF: 54.40691683928921
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 54.40691434005315
#             Iterations: 26
#             Function evaluations: 219
#             Gradient evaluations: 26
# Iteration:      4,   Func. Count:     42,   Neg. LLF: 96.46926768325412
# Iteration:      8,   Func. Count:     76,   Neg. LLF: 55.43542195208849
# Iteration:     12,   Func. Count:    108,   Neg. LLF: 55.22201556885344
# Iteration:     16,   Func. Count:    140,   Neg. LLF: 55.1615112649753
# Iteration:     20,   Func. Count:    173,   Neg. LLF: 55.07644380586545
# Iteration:     24,   Func. Count:    205,   Neg. LLF: 55.06615949812573
# Iteration:     28,   Func. Count:    237,   Neg. LLF: 55.06538341212439
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 55.06538341212439
#             Iterations: 28
#             Function evaluations: 237
#             Gradient evaluations: 28
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 203.9470931594177
# Iteration:      8,   Func. Count:     76,   Neg. LLF: 55.562535645179636
# Iteration:     12,   Func. Count:    108,   Neg. LLF: 55.17773362582403
# Iteration:     16,   Func. Count:    140,   Neg. LLF: 55.05213464131076
# Iteration:     20,   Func. Count:    172,   Neg. LLF: 55.01140576383703
# Iteration:     24,   Func. Count:    204,   Neg. LLF: 55.01137564443896
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 55.0113699258701
#             Iterations: 26
#             Function evaluations: 220
#             Gradient evaluations: 26
# ('daily_return', 'EGARCH')
#                      h.1
# 2015-11-30  1.967125e-01
# 2015-12-31  2.409767e-01
# 2016-01-31  1.996317e-01
# 2016-02-29  1.758608e+08
# 2016-03-31  1.596292e-01
# ...                  ...
# 2021-01-31  1.416131e-01
# 2021-02-28  1.040978e-01
# 2021-03-31  1.252945e-01
# 2021-04-30  1.853586e-01
# 2021-05-31  1.092788e-01
#
# [67 rows x 1 columns]
